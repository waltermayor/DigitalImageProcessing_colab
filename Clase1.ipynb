# %% [markdown]
# <a href="https://colab.research.google.com/github/waltermayor/DigitalImageProcessing_colab/blob/master/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Configurar folder de imagenes de prueba

# %%
from google.colab import drive
drive.mount('/content/drive')

path_clone = "/content/drive/My Drive/colab/images/"
# !cd path_clone
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: line 0: cd: path_clone: No such file or directory

# %% [markdown]
# # **Importar las librerias necesarias**

# %%
# importar librerias necesarias 

import numpy as np
import matplotlib.pyplot as plt
import cv2

# graficar imagenes estaticas en el notebook
# %matplotlib inline

# %% [markdown]
# # **Cargan imagen en formato original y visualizar**

# %%
# leer una imagen 
img_BGR=cv2.imread('/content/drive/My Drive/colab/images/playa.jpg',cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# # **Remover numeración de los ejes**

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # **Cambiar de BGR a RGB**

# %%
# pasar la imagen a rgb
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Convertir a escala de grices

# %%
# pasar la imagen a gris
img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Convertir a escala de grices

# %%
# pasar la imagen a gris

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Usar metodos para mostrar las imagenes

# %%
# Display two images
def display(a, b, title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# Display one image
def display_one(a, title1 = "Original"):
    plt.imshow(a), plt.title(title1)
    plt.show()
    
display_one(img_BGR)

# %%
display(img_BGR,img_RGB,"BGR","RGB")

# %%
# Display four images
def display4(a, b,c,d,title1 = "Original", title2 = "Edited", title3 = "Edited", title4 = "Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(221), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223), plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224), plt.imshow(d,cmap='gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display4(img_BGR,img_RGB,img_GRAY,img_GRAY,"BRG","RGB","GRAY","GRAY")

# %% [markdown]
# # Caracteristicas de la imagen

# %%
def estadisticas(img):
  
  img_size=img.shape
  
  if len(img_size)>2:
    print("image chanels",img_size[2])
  else:
    print("image chanels",2)
    
  print("image W",img_size[1])
  print("image H",img_size[0])
  print("min value",img.min())
  print("max value",img.max())
  print("prom",img.mean())
  print("type",img.dtype)
    

estadisticas(img_BGR)
# Out:
# image chanels 3
# image W 2000
# image H 1519
# min value 0
# max value 255
# prom 166.58686844415186
# type uint8
